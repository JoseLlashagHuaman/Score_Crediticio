# %% [markdown]
# ## **Credit Score Classification**

# %% [markdown]
# ## **Alumno: José Llashag Huamán**

# %% [markdown]
# ## I. Introducción<a class="anchor" id="Seccion_II"></a>

# %% [markdown]
# **Problema:**
#
# Está trabajando como científico de datos en una compañía financiera global. A lo largo de los años, la empresa ha recopilado datos bancarios básicos y mucha información relacionada con el crédito. La gerencia quiere construir un sistema inteligente para segregar a las personas entramos de puntaje de crédito para reducir los esfuerzos manuales.

# %% [markdown]
# **Objetivo:**
#
# Dada la información relacionada con el crédito de una persona, cree un modelo de aprendizaje automático que pueda clasificar el puntaje crediticio.

# %% [markdown]
# ## II. Importación de librerias y Carga de dataset<a class="anchor" id="Seccion_II"></a>

# %% [markdown]
# ### 2.1. Importación de Librerias<a class="anchor" id="Seccion_II_2_1"></a>

# %%
import sklearn
sklearn.__version__
# Out:
# '1.2.2'

# %%
import pandas as pd
import numpy as np

# %%
from pycaret.datasets import get_data

# %%
from pycaret.classification import *

# %% [markdown]
# ### 2.2. Carga de dataset<a class="anchor" id="Seccion_II_2_2"></a>

# %% [markdown]
# Carga del dataset de entrenamiento

# %%
dataset_train = pd.read_csv('datasets/train.csv', encoding='latin-1')

# %% [markdown]
# Carga del dataset de test

# %%
dataset_test = pd.read_csv('datasets/test.csv', encoding='latin-1')

# %% [markdown]
# ## III. Análisis de Variables y Limpieza de valores<a class="anchor" id="Seccion_III"></a>

# %% [markdown]
# ### 3.1. Análisis de Variables<a class="anchor" id="Seccion_II_2_3"></a>

# %% [markdown]
# Número de variables y cantidad de datos

# %%
dataset_train.shape
# Out:
# (100000, 28)

# %%
dataset_train.head(3)
# Out:
#        ID Customer_ID     Month           Name   Age          SSN Occupation  \
# 0  0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265  Scientist
# 1  0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265  Scientist
# 2  0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265  Scientist
#
#   Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  Credit_Mix  \
# 0      19114.12            1824.843333                  3  ...           _
# 1      19114.12                    NaN                  3  ...        Good
# 2      19114.12                    NaN                  3  ...        Good
#
#    Outstanding_Debt Credit_Utilization_Ratio     Credit_History_Age  \
# 0            809.98                26.822620  22 Years and 1 Months
# 1            809.98                31.944960                    NaN
# 2            809.98                28.609352  22 Years and 3 Months
#
#    Payment_of_Min_Amount Total_EMI_per_month Amount_invested_monthly  \
# 0                     No           49.574949       80.41529543900253
# 1                     No           49.574949      118.28022162236736
# 2                     No           49.574949         81.699521264648
#
#                  Payment_Behaviour     Monthly_Balance Credit_Score
# 0  High_spent_Small_value_payments  312.49408867943663         Good
# 1   Low_spent_Large_value_payments  284.62916249607184         Good
# 2  Low_spent_Medium_value_payments   331.2098628537912         Good
#
# [3 rows x 28 columns]

# %% [markdown]
# Se cuenta con 8 variables numericas y 20 variables cualitativas incluyendo el target (Credit_Score)

# %%
dataset_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 28 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ID                        100000 non-null  object
#  1   Customer_ID               100000 non-null  object
#  2   Month                     100000 non-null  object
#  3   Name                      90015 non-null   object
#  4   Age                       100000 non-null  object
#  5   SSN                       100000 non-null  object
#  6   Occupation                100000 non-null  object
#  7   Annual_Income             100000 non-null  object
#  8   Monthly_Inhand_Salary     84998 non-null   float64
#  9   Num_Bank_Accounts         100000 non-null  int64
#  10  Num_Credit_Card           100000 non-null  int64
#  11  Interest_Rate             100000 non-null  int64
#  12  Num_of_Loan               100000 non-null  object
#  13  Type_of_Loan              88592 non-null   object
#  14  Delay_from_due_date       100000 non-null  int64
#  15  Num_of_Delayed_Payment    92998 non-null   object
#  16  Changed_Credit_Limit      100000 non-null  object
#  17  Num_Credit_Inquiries      98035 non-null   float64
#  18  Credit_Mix                100000 non-null  object
#  19  Outstanding_Debt          100000 non-null  object
#  20  Credit_Utilization_Ratio  100000 non-null  float64
#  21  Credit_History_Age        90970 non-null   object
#  22  Payment_of_Min_Amount     100000 non-null  object
#  23  Total_EMI_per_month       100000 non-null  float64
#  24  Amount_invested_monthly   95521 non-null   object
#  25  Payment_Behaviour         100000 non-null  object
#  26  Monthly_Balance           98800 non-null   object
#  27  Credit_Score              100000 non-null  object
# dtypes: float64(4), int64(4), object(20)
# memory usage: 21.4+ MB

# %% [markdown]
# Se cuenta la cantidad de variables nulos

# %%
dataset_train.isna().sum().sort_values()
# Out:
# ID                              0
# Payment_Behaviour               0
# Total_EMI_per_month             0
# Payment_of_Min_Amount           0
# Credit_Utilization_Ratio        0
# Outstanding_Debt                0
# Credit_Mix                      0
# Changed_Credit_Limit            0
# Delay_from_due_date             0
# Num_of_Loan                     0
# Interest_Rate                   0
# Credit_Score                    0
# Num_Bank_Accounts               0
# Annual_Income                   0
# Occupation                      0
# SSN                             0
# Age                             0
# Month                           0
# Customer_ID                     0
# Num_Credit_Card                 0
# Monthly_Balance              1200
# Num_Credit_Inquiries         1965
# Amount_invested_monthly      4479
# Num_of_Delayed_Payment       7002
# Credit_History_Age           9030
# Name                         9985
# Type_of_Loan                11408
# Monthly_Inhand_Salary       15002
# dtype: int64

# %% [markdown]
# ### 3.2. Limpieza de valores<a class="anchor" id="Seccion_II_2_4"></a>

# %%
def isfloat(num):
  try:
      float(str(num).replace('__', "").replace('_', ""))
      return True
  except ValueError:
      return False

# %% [markdown]
# Limpieza de valores irregulares

# %%
#Para la data de entrennamiento
dataset_train = dataset_train.replace(to_replace=r'!@9#%8', value='', regex=True)
dataset_train = dataset_train.replace(to_replace=r'#F%$D@*&8', value='', regex=True)
dataset_train = dataset_train.replace('_______', "")
dataset_train = dataset_train.replace('__', "")
dataset_train = dataset_train.replace('_', "")

#Para la data de prueba
dataset_test = dataset_test.replace(to_replace=r'!@9#%8', value='', regex=True)
dataset_test = dataset_test.replace(to_replace=r'#F%$D@*&8', value='', regex=True)
dataset_test = dataset_test.replace('_______', "")
dataset_test = dataset_test.replace('__', "")
dataset_test = dataset_test.replace('_', "")

# %% [markdown]
# Limpieza de variables nulos

# %%
dataset_train = dataset_train.fillna(method='ffill').fillna(method='bfill')
dataset_test = dataset_test.fillna(method='ffill').fillna(method='bfill')

# %% [markdown]
# Se cuenta la cantidad de variables nulos

# %%
dataset_train.isna().sum().sort_values()
# Out:
# ID                          0
# Payment_Behaviour           0
# Amount_invested_monthly     0
# Total_EMI_per_month         0
# Payment_of_Min_Amount       0
# Credit_History_Age          0
# Credit_Utilization_Ratio    0
# Outstanding_Debt            0
# Credit_Mix                  0
# Num_Credit_Inquiries        0
# Changed_Credit_Limit        0
# Num_of_Delayed_Payment      0
# Delay_from_due_date         0
# Type_of_Loan                0
# Num_of_Loan                 0
# Interest_Rate               0
# Num_Credit_Card             0
# Num_Bank_Accounts           0
# Monthly_Inhand_Salary       0
# Annual_Income               0
# Occupation                  0
# SSN                         0
# Age                         0
# Name                        0
# Month                       0
# Customer_ID                 0
# Monthly_Balance             0
# Credit_Score                0
# dtype: int64

# %% [markdown]
# Limpieza de la variable Age

# %%
dataset_train['Age'].describe()
# Out:
# count     100000
# unique      1788
# top           38
# freq        2833
# Name: Age, dtype: object

# %%
dataset_train['Age'] = dataset_train['Age'].apply(lambda x : int(x.replace('__', "").replace('_', "")) if isfloat(x) else int(0))
dataset_test['Age'] = dataset_test['Age'].apply(lambda x : int(x.replace('__', "").replace('_', "")) if isfloat(x) else int(0))

# %%
dataset_train['Age'].describe()
# Out:
# count    100000.000000
# mean        110.649700
# std         686.244717
# min        -500.000000
# 25%          24.000000
# 50%          33.000000
# 75%          42.000000
# max        8698.000000
# Name: Age, dtype: float64

# %% [markdown]
# Limpieza de la variable Annual_Income

# %%
dataset_train['Annual_Income'].describe()
# Out:
# count       100000
# unique       18940
# top       36585.12
# freq            16
# Name: Annual_Income, dtype: object

# %%
dataset_train['Annual_Income'] = dataset_train['Annual_Income'].apply(lambda x : float(x.replace('__', "").replace('_', "")) if isfloat(x) else float(0))
dataset_test['Annual_Income'] = dataset_test['Annual_Income'].apply(lambda x : float(x.replace('__', "").replace('_', "")) if isfloat(x) else float(0))

# %%
dataset_train['Annual_Income'].describe()
# Out:
# count    1.000000e+05
# mean     1.764157e+05
# std      1.429618e+06
# min      7.005930e+03
# 25%      1.945750e+04
# 50%      3.757861e+04
# 75%      7.279092e+04
# max      2.419806e+07
# Name: Annual_Income, dtype: float64

# %% [markdown]
# Limpieza de la variable Changed_Credit_Limit

# %%
dataset_train['Changed_Credit_Limit'].describe()
# Out:
# count     100000
# unique      4384
# top
# freq        2091
# Name: Changed_Credit_Limit, dtype: object

# %%
dataset_train['Changed_Credit_Limit'] = dataset_train['Changed_Credit_Limit'].apply(lambda x : float(x.replace('__', "").replace('_', "")) if isfloat(x) else float(0))
dataset_test['Changed_Credit_Limit'] = dataset_test['Changed_Credit_Limit'].apply(lambda x : float(x.replace('__', "").replace('_', "")) if isfloat(x) else float(0))

# %%
dataset_train['Changed_Credit_Limit'].describe()
# Out:
# count    100000.000000
# mean         10.171791
# std           6.880628
# min          -6.490000
# 25%           4.970000
# 50%           9.250000
# 75%          14.660000
# max          36.970000
# Name: Changed_Credit_Limit, dtype: float64

# %% [markdown]
# Limpieza de la variable Outstanding_Debt

# %%
dataset_train['Outstanding_Debt'].describe()
# Out:
# count      100000
# unique      13178
# top       1360.45
# freq           24
# Name: Outstanding_Debt, dtype: object

# %%
dataset_train['Outstanding_Debt'] = dataset_train['Outstanding_Debt'].apply(lambda x : float(x.replace('__', "").replace('_', "")) if isfloat(x) else float(0))
dataset_test['Outstanding_Debt'] = dataset_test['Outstanding_Debt'].apply(lambda x : float(x.replace('__', "").replace('_', "")) if isfloat(x) else float(0))

# %%
dataset_train['Outstanding_Debt'].describe()
# Out:
# count    100000.000000
# mean       1426.220376
# std        1155.129026
# min           0.230000
# 25%         566.072500
# 50%        1166.155000
# 75%        1945.962500
# max        4998.070000
# Name: Outstanding_Debt, dtype: float64

# %% [markdown]
# Limpieza de la variable Amount_invested_monthly

# %%
dataset_train['Amount_invested_monthly'].describe()
# Out:
# count        100000
# unique        91049
# top       __10000__
# freq           4500
# Name: Amount_invested_monthly, dtype: object

# %%
dataset_train['Amount_invested_monthly'] = dataset_train['Amount_invested_monthly'].apply(lambda x : float(x.replace('__', "").replace('_', "")) if isfloat(x) else float(0))
dataset_test['Amount_invested_monthly'] = dataset_test['Amount_invested_monthly'].apply(lambda x : float(x.replace('__', "").replace('_', "")) if isfloat(x) else float(0))

# %%
dataset_train['Amount_invested_monthly'].describe()
# Out:
# count    100000.000000
# mean        636.932570
# std        2041.827136
# min           0.000000
# 25%          74.616863
# 50%         135.959898
# 75%         266.118215
# max       10000.000000
# Name: Amount_invested_monthly, dtype: float64

# %% [markdown]
# Limpieza de la variable Monthly_Balance

# %%
dataset_train['Monthly_Balance'].describe()
# Out:
# count                               100000
# unique                               98792
# top       __-333333333333333333333333333__
# freq                                     9
# Name: Monthly_Balance, dtype: object

# %%
dataset_train['Monthly_Balance'] = dataset_train['Monthly_Balance'].apply(lambda x : float(str(x).replace('__', "").replace('_', "")) if isfloat(x) else float(0))
dataset_test['Monthly_Balance'] = dataset_test['Monthly_Balance'].apply(lambda x : float(str(x).replace('__', "").replace('_', "")) if isfloat(x) else float(0))

# %%
dataset_train['Monthly_Balance'].describe()
# Out:
# count    1.000000e+05
# mean    -3.000000e+22
# std      3.162151e+24
# min     -3.333333e+26
# 25%      2.700394e+02
# 50%      3.370244e+02
# 75%      4.714038e+02
# max      1.602041e+03
# Name: Monthly_Balance, dtype: float64

# %% [markdown]
# Cantidad de variable Credit_Score

# %%
dataset_train['Credit_Score'].value_counts()
# Out:
# Standard    53174
# Poor        28998
# Good        17828
# Name: Credit_Score, dtype: int64

# %% [markdown]
# Se elimina algunos campos que no servirán para la predicción

# %%
dataset_train = dataset_train.drop("ID", axis=1)
dataset_train = dataset_train.drop("Name", axis=1)
dataset_train = dataset_train.drop("Type_of_Loan", axis=1)
dataset_train = dataset_train.drop("SSN", axis=1)
dataset_train = dataset_train.drop("Monthly_Inhand_Salary", axis=1)
dataset_train = dataset_train.drop("Credit_History_Age", axis=1)
dataset_train = dataset_train.drop("Num_Credit_Inquiries", axis=1)

dataset_test = dataset_test.drop("ID", axis=1)
dataset_test = dataset_test.drop("Name", axis=1)
dataset_test = dataset_test.drop("Type_of_Loan", axis=1)
dataset_test = dataset_test.drop("SSN", axis=1)
dataset_test = dataset_test.drop("Monthly_Inhand_Salary", axis=1)
dataset_test = dataset_test.drop("Credit_History_Age", axis=1)
dataset_test = dataset_test.drop("Num_Credit_Inquiries", axis=1)

# %% [markdown]
# Nos quedamos en total con 22 columnas

# %%
dataset_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   Customer_ID               100000 non-null  object
#  1   Month                     100000 non-null  object
#  2   Age                       100000 non-null  int64
#  3   Occupation                100000 non-null  object
#  4   Annual_Income             100000 non-null  float64
#  5   Num_Bank_Accounts         100000 non-null  int64
#  6   Num_Credit_Card           100000 non-null  int64
#  7   Interest_Rate             100000 non-null  int64
#  8   Num_of_Loan               100000 non-null  object
#  9   Delay_from_due_date       100000 non-null  int64
#  10  Num_of_Delayed_Payment    100000 non-null  object
#  11  Changed_Credit_Limit      100000 non-null  float64
#  12  Credit_Mix                100000 non-null  object
#  13  Outstanding_Debt          100000 non-null  float64
#  14  Credit_Utilization_Ratio  100000 non-null  float64
#  15  Payment_of_Min_Amount     100000 non-null  object
#  16  Total_EMI_per_month       100000 non-null  float64
#  17  Amount_invested_monthly   100000 non-null  float64
#  18  Payment_Behaviour         100000 non-null  object
#  19  Monthly_Balance           100000 non-null  float64
#  20  Credit_Score              100000 non-null  object
# dtypes: float64(7), int64(5), object(9)
# memory usage: 16.0+ MB

# %% [markdown]
# Sacamos un muestra de la data total

# %%
dataset_train_sample = dataset_train.sample(n=12500)
dataset_train_sample.shape

dataset_test_sample = dataset_test.sample(n=12500)
dataset_test_sample.shape
# Out:
# (12500, 20)

# %% [markdown]
# ## IV. Uso del dataset de Pycaret

# %% [markdown]
# Se ejecuta el setup

# %%
dataset_credit = setup(data=dataset_train_sample, target='Credit_Score', session_id=123)

# %% [markdown]
# Evaluar el mejor modelo

# %%
best = compare_models()

# %% [markdown]
# Obtener mejor estimadores del mejor modelo

# %%
tuned_best = tune_model(estimator = best)
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   01:01:04
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .   Random Forest Classifier
# <style type="text/css">
# #T_9bfab_row10_col0, #T_9bfab_row10_col1, #T_9bfab_row10_col2, #T_9bfab_row10_col3, #T_9bfab_row10_col4, #T_9bfab_row10_col5, #T_9bfab_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_9bfab">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9bfab_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_9bfab_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_9bfab_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_9bfab_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_9bfab_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_9bfab_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_9bfab_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9bfab_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9bfab_row0_col0" class="data row0 col0" >0.6960</td>
#       <td id="T_9bfab_row0_col1" class="data row0 col1" >0.8075</td>
#       <td id="T_9bfab_row0_col2" class="data row0 col2" >0.6960</td>
#       <td id="T_9bfab_row0_col3" class="data row0 col3" >0.7595</td>
#       <td id="T_9bfab_row0_col4" class="data row0 col4" >0.7028</td>
#       <td id="T_9bfab_row0_col5" class="data row0 col5" >0.5374</td>
#       <td id="T_9bfab_row0_col6" class="data row0 col6" >0.5597</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_9bfab_row1_col0" class="data row1 col0" >0.6629</td>
#       <td id="T_9bfab_row1_col1" class="data row1 col1" >0.7828</td>
#       <td id="T_9bfab_row1_col2" class="data row1 col2" >0.6629</td>
#       <td id="T_9bfab_row1_col3" class="data row1 col3" >0.7264</td>
#       <td id="T_9bfab_row1_col4" class="data row1 col4" >0.6672</td>
#       <td id="T_9bfab_row1_col5" class="data row1 col5" >0.4894</td>
#       <td id="T_9bfab_row1_col6" class="data row1 col6" >0.5122</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_9bfab_row2_col0" class="data row2 col0" >0.6709</td>
#       <td id="T_9bfab_row2_col1" class="data row2 col1" >0.7893</td>
#       <td id="T_9bfab_row2_col2" class="data row2 col2" >0.6709</td>
#       <td id="T_9bfab_row2_col3" class="data row2 col3" >0.7417</td>
#       <td id="T_9bfab_row2_col4" class="data row2 col4" >0.6750</td>
#       <td id="T_9bfab_row2_col5" class="data row2 col5" >0.5038</td>
#       <td id="T_9bfab_row2_col6" class="data row2 col6" >0.5297</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_9bfab_row3_col0" class="data row3 col0" >0.6629</td>
#       <td id="T_9bfab_row3_col1" class="data row3 col1" >0.7968</td>
#       <td id="T_9bfab_row3_col2" class="data row3 col2" >0.6629</td>
#       <td id="T_9bfab_row3_col3" class="data row3 col3" >0.7302</td>
#       <td id="T_9bfab_row3_col4" class="data row3 col4" >0.6683</td>
#       <td id="T_9bfab_row3_col5" class="data row3 col5" >0.4898</td>
#       <td id="T_9bfab_row3_col6" class="data row3 col6" >0.5130</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_9bfab_row4_col0" class="data row4 col0" >0.6617</td>
#       <td id="T_9bfab_row4_col1" class="data row4 col1" >0.7889</td>
#       <td id="T_9bfab_row4_col2" class="data row4 col2" >0.6617</td>
#       <td id="T_9bfab_row4_col3" class="data row4 col3" >0.7335</td>
#       <td id="T_9bfab_row4_col4" class="data row4 col4" >0.6673</td>
#       <td id="T_9bfab_row4_col5" class="data row4 col5" >0.4891</td>
#       <td id="T_9bfab_row4_col6" class="data row4 col6" >0.5134</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_9bfab_row5_col0" class="data row5 col0" >0.6503</td>
#       <td id="T_9bfab_row5_col1" class="data row5 col1" >0.7792</td>
#       <td id="T_9bfab_row5_col2" class="data row5 col2" >0.6503</td>
#       <td id="T_9bfab_row5_col3" class="data row5 col3" >0.7151</td>
#       <td id="T_9bfab_row5_col4" class="data row5 col4" >0.6546</td>
#       <td id="T_9bfab_row5_col5" class="data row5 col5" >0.4706</td>
#       <td id="T_9bfab_row5_col6" class="data row5 col6" >0.4930</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_9bfab_row6_col0" class="data row6 col0" >0.6549</td>
#       <td id="T_9bfab_row6_col1" class="data row6 col1" >0.7873</td>
#       <td id="T_9bfab_row6_col2" class="data row6 col2" >0.6549</td>
#       <td id="T_9bfab_row6_col3" class="data row6 col3" >0.7269</td>
#       <td id="T_9bfab_row6_col4" class="data row6 col4" >0.6615</td>
#       <td id="T_9bfab_row6_col5" class="data row6 col5" >0.4789</td>
#       <td id="T_9bfab_row6_col6" class="data row6 col6" >0.5027</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_9bfab_row7_col0" class="data row7 col0" >0.6514</td>
#       <td id="T_9bfab_row7_col1" class="data row7 col1" >0.7905</td>
#       <td id="T_9bfab_row7_col2" class="data row7 col2" >0.6514</td>
#       <td id="T_9bfab_row7_col3" class="data row7 col3" >0.7377</td>
#       <td id="T_9bfab_row7_col4" class="data row7 col4" >0.6554</td>
#       <td id="T_9bfab_row7_col5" class="data row7 col5" >0.4807</td>
#       <td id="T_9bfab_row7_col6" class="data row7 col6" >0.5114</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_9bfab_row8_col0" class="data row8 col0" >0.6720</td>
#       <td id="T_9bfab_row8_col1" class="data row8 col1" >0.7964</td>
#       <td id="T_9bfab_row8_col2" class="data row8 col2" >0.6720</td>
#       <td id="T_9bfab_row8_col3" class="data row8 col3" >0.7416</td>
#       <td id="T_9bfab_row8_col4" class="data row8 col4" >0.6749</td>
#       <td id="T_9bfab_row8_col5" class="data row8 col5" >0.5057</td>
#       <td id="T_9bfab_row8_col6" class="data row8 col6" >0.5319</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_9bfab_row9_col0" class="data row9 col0" >0.6583</td>
#       <td id="T_9bfab_row9_col1" class="data row9 col1" >0.7779</td>
#       <td id="T_9bfab_row9_col2" class="data row9 col2" >0.6583</td>
#       <td id="T_9bfab_row9_col3" class="data row9 col3" >0.7221</td>
#       <td id="T_9bfab_row9_col4" class="data row9 col4" >0.6640</td>
#       <td id="T_9bfab_row9_col5" class="data row9 col5" >0.4812</td>
#       <td id="T_9bfab_row9_col6" class="data row9 col6" >0.5026</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_9bfab_row10_col0" class="data row10 col0" >0.6641</td>
#       <td id="T_9bfab_row10_col1" class="data row10 col1" >0.7897</td>
#       <td id="T_9bfab_row10_col2" class="data row10 col2" >0.6641</td>
#       <td id="T_9bfab_row10_col3" class="data row10 col3" >0.7335</td>
#       <td id="T_9bfab_row10_col4" class="data row10 col4" >0.6691</td>
#       <td id="T_9bfab_row10_col5" class="data row10 col5" >0.4927</td>
#       <td id="T_9bfab_row10_col6" class="data row10 col6" >0.5170</td>
#     </tr>
#     <tr>
#       <th id="T_9bfab_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_9bfab_row11_col0" class="data row11 col0" >0.0127</td>
#       <td id="T_9bfab_row11_col1" class="data row11 col1" >0.0085</td>
#       <td id="T_9bfab_row11_col2" class="data row11 col2" >0.0127</td>
#       <td id="T_9bfab_row11_col3" class="data row11 col3" >0.0118</td>
#       <td id="T_9bfab_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits

# %% [markdown]
# Entremamiento y evaluación del modelo

# %%
final_model = finalize_model(estimator = tuned_best)

# %%
evaluate_model(final_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…

# %% [markdown]
# Probar el modelo

# %%
predict_model(final_model, data = dataset_test_sample)
# Out:
#       Customer_ID      Month  Age    Occupation  Annual_Income  \
# 0      CUS_0x8142  September   22  Entrepreneur   31156.179688
# 1      CUS_0x4056    October   46     Developer   71842.796875
# 2      CUS_0xa224    October   26    Accountant    9166.464844
# 3      CUS_0x9124  September   24  Entrepreneur   52561.621094
# 4      CUS_0x5d6d   November   39        Writer  126514.718750
# ...           ...        ...  ...           ...            ...
# 12495  CUS_0xa95d  September   47     Architect   38690.039062
# 12496  CUS_0x487a  September   27     Scientist   58728.058594
# 12497  CUS_0x3d60  September   24       Teacher   40289.789062
# 12498  CUS_0x58aa  September   41                  7664.314941
# 12499  CUS_0x1edc    October   20       Manager   62152.589844
#
#        Num_Bank_Accounts  Num_Credit_Card  Interest_Rate Num_of_Loan  \
# 0                      7                4             15           5
# 1                      3                7             12           2
# 2                      9             1363             22           3
# 3                      8                8             32           2
# 4                      8                7              5           3
# ...                  ...              ...            ...         ...
# 12495                  5                3             16           2
# 12496                  8                5             18           5
# 12497                  5                6             10           2
# 12498                  6                5             15           5
# 12499                  8                4             12           2
#
#        Delay_from_due_date  ... Credit_Mix  Outstanding_Debt  \
# 0                        5  ...   Standard        159.080002
# 1                       18  ...   Standard         39.310001
# 2                       13  ...                  1943.209961
# 3                       30  ...   Standard       1312.290039
# 4                       21  ...   Standard        470.420013
# ...                    ...  ...        ...               ...
# 12495                   11  ...   Standard        590.940002
# 12496                    5  ...                  1272.790039
# 12497                   11  ...       Good       1073.739990
# 12498                   36  ...   Standard       1294.449951
# 12499                    9  ...   Standard        874.599976
#
#       Credit_Utilization_Ratio  Payment_of_Min_Amount  Total_EMI_per_month  \
# 0                    27.886053                    Yes           113.901184
# 1                    34.422684                     No            65.273575
# 2                    26.799608                    Yes            21.385996
# 3                    33.199986                    Yes            48.935272
# 4                    39.855457                     No           312.032867
# ...                        ...                    ...                  ...
# 12495                28.963427                    Yes            40.095337
# 12496                41.076851                    Yes           129.832825
# 12497                32.286114                     NM            38.976391
# 12498                36.152924                    Yes            24.236105
# 12499                38.954170                    Yes            99.346939
#
#       Amount_invested_monthly                 Payment_Behaviour  \
# 0                  128.070190    Low_spent_Large_value_payments
# 1                   70.093201   High_spent_Large_value_payments
# 2                   14.261943   High_spent_Small_value_payments
# 3                  286.340485   High_spent_Small_value_payments
# 4                  387.999115    Low_spent_Large_value_payments
# ...                       ...                               ...
# 12495               71.680115
# 12496              130.280716  High_spent_Medium_value_payments
# 12497              101.192390  High_spent_Medium_value_payments
# 12498               23.742453   High_spent_Large_value_payments
# 12499              465.564941    Low_spent_Large_value_payments
#
#        Monthly_Balance prediction_label  prediction_score
# 0           274.863464         Standard              0.75
# 1           714.823242         Standard              0.63
# 2           276.139282             Poor              0.70
# 3           381.937744             Poor              0.71
# 4           604.157349         Standard              0.82
# ...                ...              ...               ...
# 12495       445.641541         Standard              0.81
# 12496       553.835083             Poor              0.49
# 12497       417.179474         Standard              0.54
# 12498       283.890747             Poor              0.59
# 12499       223.926376         Standard              0.74
#
# [12500 rows x 22 columns]

# %% [markdown]
# Guardar el modelo

# %%
save_model(final_model, 'Credit_Score_Model')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=C:\Users\josel\AppData\Local\Temp\joblib),
#           steps=[('label_encoding',
#                   TransformerWrapperWithInverse(exclude=None, include=None,
#                                                 transformer=LabelEncoder())),
#                  ('numerical_imputer',
#                   TransformerWrapper(exclude=None,
#                                      include=['Age', 'Annual_Income',
#                                               'Num_Bank_Accounts',
#                                               'Num_Credit_Card', 'Interest_Rate',
#                                               'Delay_from_due_date',
#                                               'C...
#                   RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                          class_weight=None, criterion='gini',
#                                          max_depth=None, max_features='sqrt',
#                                          max_leaf_nodes=None, max_samples=None,
#                                          min_impurity_decrease=0.0,
#                                          min_samples_leaf=1, min_samples_split=2,
#                                          min_weight_fraction_leaf=0.0,
#                                          n_estimators=100, n_jobs=-1,
#                                          oob_score=False, random_state=123,
#                                          verbose=0, warm_start=False))],
#           verbose=False),
#  'Credit_Score_Model.pkl')
